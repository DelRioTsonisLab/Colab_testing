# %%
from google.colab import files
from IPython.display import Image, display

print("Upload your image file:")
uploaded = files.upload()

for filename in uploaded.keys():
  print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
  # Display the uploaded image
  display(Image(filename))
# Out:
# Upload your image file:
#      <input type="file" id="files-12d9d447-711c-462a-8bc6-069419657235" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-12d9d447-711c-462a-8bc6-069419657235">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# **Reasoning**:
# A descriptive summary of the heatmap is generated and stored in the `heatmap_summary` variable, fulfilling the subtask's requirement to explain what the heatmap visualizes and highlight prominent features, based on the provided filename context and general heatmap interpretation.

# %% [markdown]
# ### Subtask
# Manually provide the gene names and observed patterns from the `tet_dev_genes_heatmap.png` image, which are necessary for the subsequent gene information search.
#
# #### Instructions
# 1. Based on your examination of the `tet_dev_genes_heatmap.png` image, provide the clearly visible gene names or identifiers. If there are many, provide a representative subset (e.g., 5-10 genes).
# 2. Describe any significant visual patterns you observed in the heatmap (e.g., distinct clusters of genes, areas of high or low expression, patterns across different samples/conditions).
# 3. Enter this information in a new code cell, assigning the gene names to a Python list named `identified_genes` and the observed patterns to a string variable named `observed_patterns`. For example:
#
# ```python
# identified_genes = ["GeneA", "GeneB", "GeneC", "GeneD", "GeneE"]
# observed_patterns = "The heatmap shows a distinct cluster of highly expressed genes in the top-left quadrant and another cluster of low-expressed genes in the bottom-right for specific conditions. There appears to be hierarchical clustering visible on both rows and columns."
# ```
#
# If no gene names are clearly visible, set `identified_genes = []`.

# %% [markdown]
# **Reasoning**:
# The user explicitly asked to add a new markdown step with specific instructions. This markdown block provides the necessary guidance for the user to manually extract gene names and patterns from the heatmap, which is a prerequisite for the next analytical steps.

# %%
### SubtaskManually provide the gene names and observed patterns from the `tet_dev_genes_heatmap.png` image, which are necessary for the subsequent gene information search.#### Instructions1. Based on your examination of the `tet_dev_genes_heatmap.png` image, provide the clearly visible gene names or identifiers. If there are many, provide a representative subset (e.g., 5-10 genes).2. Describe any significant visual patterns you observed in the heatmap (e.g., distinct clusters of genes, areas of high or low expression, patterns across different samples/conditions).3. Enter this information in a new code cell, assigning the gene names to a Python list named `identified_genes` and the observed patterns to a string variable named `observed_patterns`. For example:```pythonidentified_genes = ["GeneA", "GeneB", "GeneC", "GeneD", "GeneE"]observed_patterns = "The heatmap shows a distinct cluster of highly expressed genes in the top-left quadrant and another cluster of low-expressed genes in the bottom-right for specific conditions. There appears to be hierarchical clustering visible on both rows and columns."```If no gene names are clearly visible, set `identified_genes = []`.
